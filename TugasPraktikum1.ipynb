# %% [markdown]
# <a href="https://colab.research.google.com/github/elshaagn/TugasMLPertemuan1/blob/main/TugasPraktikum1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/elshaagn/TugasMLPertemuan1
# Out:
# Cloning into 'TugasMLPertemuan1'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 10.61 KiB | 5.30 MiB/s, done.

# %%
import pandas as pd
data = pd.read_excel('/content/TugasMLPertemuan1/disdukcapil-2-od_16994_jumlah_penduduk_cerai_mati_berdasarkan_kelompok_umur_data.xlsx')
data
# Out:
#       id  kode_provinsi nama_provinsi kategori_kelompok_umur  jumlah_penduduk  \
# 0      1             32    JAWA BARAT                    0-4               44
# 1      2             32    JAWA BARAT                    5-9              137
# 2      3             32    JAWA BARAT                  10-14              109
# 3      4             32    JAWA BARAT                  15-19              558
# 4      5             32    JAWA BARAT                  20-24             2727
# ..   ...            ...           ...                    ...              ...
# 139  140             32    JAWA BARAT                  55-59           243097
# 140  141             32    JAWA BARAT                  60-64           279800
# 141  142             32    JAWA BARAT                  65-69           275465
# 142  143             32    JAWA BARAT                  70-74           218920
# 143  144             32    JAWA BARAT                   > 75           349269
#
#     satuan  tahun
# ...
